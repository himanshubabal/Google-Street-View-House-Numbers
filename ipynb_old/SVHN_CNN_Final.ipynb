# %%
import numpy as np
import tensorflow as tf
import random
import math
import h5py
import gc
import sys

# %%
def acc(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 2).T == labels) / predictions.shape[1] / predictions.shape[0])

# %%
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

# %%
hdf_file = 'datasets/pickles/SVHN_multi_box.hdf5'

hdf = h5py.File(hdf_file,'r')
train_dataset = hdf['train_images'][:]
train_labels = hdf['train_labels'][:]
test_dataset = hdf['test_images'][:]
test_labels = hdf['test_labels'][:]
valid_dataset = hdf['valid_images'][:]
valid_labels = hdf['valid_labels'][:]
            
hdf.close()    

print('Training set', train_dataset.shape, train_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
# Out:
# Training set (230070, 32, 96, 1) (230070, 6)
# Test set (13068, 32, 96, 1) (13068, 6)
# Validation set (5684, 32, 96, 1) (5684, 6)

# %%
train_dataset = train_dataset.astype(np.float32)
test_dataset = test_dataset.astype(np.float32)
valid_dataset = valid_dataset.astype(np.float32)

train_labels = train_labels.astype(np.int32)
test_labels = test_labels.astype(np.int32)
valid_labels = valid_labels.astype(np.int32)

# %%
saved_model = "saved_models/box/CNN_SVHN_Box.ckpt"
model_to_save = "saved_models/final/CNN_SVHN_Final.ckpt"

# %%
graph_svhn = tf.Graph()

with graph_svhn.as_default():
    HEIGHT = 32
    WIDTH = 32*3
    
    X = tf.placeholder(tf.float32, [None, HEIGHT, WIDTH, 1])
    Y_ = tf.placeholder(tf.int32, [None, 6])
    
    # Learning Rate - alpha
    alpha = tf.placeholder(tf.float32)
    
    # Dropout Probablity
    pkeep = tf.placeholder(tf.float32)
    
    # 5 Layers and their no of neurons
    # 3 Convolutional Layers and a fully connected layer
    K = 6     # First Conv Layer with depth 6
    L = 12     # Second Conv Layer with depth 12
    M = 24    # Third Conv layer with depth 24
    N = 200   # Fourth Fully Connected layer with 200 neurons
    # Last one will be softmax layer with 10 output channels
    
    W1 = tf.Variable(tf.truncated_normal([6, 6, 1, K], stddev=0.1), name="W1")    # 6x6 patch, 1 input channel, K output channels
    B1 = tf.Variable(tf.constant(0.1, tf.float32, [K]), name="B1")
    
    W2 = tf.Variable(tf.truncated_normal([5, 5, K, L], stddev=0.1), name="W2")
    B2 = tf.Variable(tf.constant(0.1, tf.float32, [L]), name="B2")
    
    W3 = tf.Variable(tf.truncated_normal([4, 4, L, M], stddev=0.1), name="W3")
    B3 = tf.Variable(tf.constant(0.1, tf.float32, [M]), name="B3")
    
    W5_1 = tf.Variable(tf.truncated_normal([N, 11], stddev=0.1), name="W5_1")
    B5_1 = tf.Variable(tf.constant(0.1, tf.float32, [11]), name="B5_1")
    
    W5_2 = tf.Variable(tf.truncated_normal([N, 11], stddev=0.1), name="W5_2")
    B5_2 = tf.Variable(tf.constant(0.1, tf.float32, [11]), name="B5_2")
    
    W5_3 = tf.Variable(tf.truncated_normal([N, 11], stddev=0.1), name="W5_3")
    B5_3 = tf.Variable(tf.constant(0.1, tf.float32, [11]), name="B5_3")
    
    W5_4 = tf.Variable(tf.truncated_normal([N, 11], stddev=0.1), name="W5_4")
    B5_4 = tf.Variable(tf.constant(0.1, tf.float32, [11]), name="B5_4")
    
    W5_5 = tf.Variable(tf.truncated_normal([N, 11], stddev=0.1), name="W5_5")
    B5_5 = tf.Variable(tf.constant(0.1, tf.float32, [11]), name="B5_5")
    
    # Model
    stride = 1  # output is 32x96
    Y1 = tf.nn.relu(tf.nn.conv2d(X, W1, strides=[1, stride, stride, 1], padding='SAME') + B1)
    
    stride = 2  # output is 16x48
    Y2 = tf.nn.relu(tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME') + B2)
    
    stride = 2  # output is 8x24
    Y3 = tf.nn.relu(tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME') + B3)

    # reshape the output from the third convolution for the fully connected layer
    shape = Y3.get_shape().as_list()
    YY = tf.reshape(Y3, shape=[-1, shape[1] * shape[2] * shape[3]])
    
    W4 = tf.Variable(tf.truncated_normal([shape[1] * shape[2] * shape[3], N], stddev=0.1), name="W4")
    B4 = tf.Variable(tf.constant(0.1, tf.float32, [N]), name="B4")

    Y4 = tf.sigmoid(tf.matmul(YY, W4) + B4)
    YY4 = tf.nn.dropout(Y4, pkeep)
    
    Ylogits_1 = tf.matmul(YY4, W5_1) + B5_1
    Ylogits_2 = tf.matmul(YY4, W5_2) + B5_2
    Ylogits_3 = tf.matmul(YY4, W5_3) + B5_3
    Ylogits_4 = tf.matmul(YY4, W5_4) + B5_4
    Ylogits_5 = tf.matmul(YY4, W5_5) + B5_5   
    ## ('Ylogits_1 shape : ', [None, 11])
    
    Y_1 = tf.nn.softmax(Ylogits_1)
    Y_2 = tf.nn.softmax(Ylogits_2)
    Y_3 = tf.nn.softmax(Ylogits_3)
    Y_4 = tf.nn.softmax(Ylogits_4)
    Y_5 = tf.nn.softmax(Ylogits_5)

    cross_entropy = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(Ylogits_1, Y_[:,1])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(Ylogits_2, Y_[:,2])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(Ylogits_3, Y_[:,3])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(Ylogits_4, Y_[:,4])) +\
    tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(Ylogits_5, Y_[:,5]))

    train_prediction = tf.pack([Y_1, Y_2, Y_3, Y_4, Y_5])
    
    train_step = tf.train.AdamOptimizer(alpha).minimize(cross_entropy)
    
    W_s = tf.pack([tf.reduce_max(tf.abs(W1)),tf.reduce_max(tf.abs(W2)),tf.reduce_max(tf.abs(W3)),tf.reduce_max(tf.abs(W4))])
    b_s = tf.pack([tf.reduce_max(tf.abs(B1)),tf.reduce_max(tf.abs(B2)),tf.reduce_max(tf.abs(B3)),tf.reduce_max(tf.abs(B4))])
    
    model_saver = tf.train.Saver()

# %%
train_data = train_dataset
label_data = train_labels
print(train_data.shape, train_labels.shape)
# Out:
# (230070, 32, 96, 1) (230070, 6)

# %%
batch_size = 128
num_steps = int(label_data.shape[0] / batch_size)
num_epochs = int(train_labels.shape[0] / batch_size)

with tf.Session(graph=graph_svhn) as session:
    model_saver.restore(session, saved_model)
    print('Initialized')
    
    for epoch in range(num_epochs-1) :
        test_d = test_dataset[epoch*batch_size:(epoch+1)*batch_size,:,:,:]
        test_l = test_labels[epoch*batch_size:(epoch+1)*batch_size,:]
        
        for step in range(num_steps-1):
            
            #  learning rate decay
            max_learning_rate = 0.0005
            min_learning_rate = 0.0001

            decay_speed = 500.0
            learning_rate = min_learning_rate + (max_learning_rate - min_learning_rate) * math.exp(-step/decay_speed)
            
            batch_data = train_data[step*batch_size:(step + 1)*batch_size, :, :, :]
            batch_labels = label_data[step*batch_size:(step + 1)*batch_size, :]

            feed_dict = {X : batch_data, Y_ : batch_labels, pkeep : 0.80, alpha : learning_rate}
            _, l, train_pred = session.run([train_step, cross_entropy, train_prediction], feed_dict=feed_dict)
            accu = acc(train_pred, batch_labels[:,1:6])
            
            if (step % 500 == 0):
                print('epoch : ',epoch+1, ' => ', 'Loss at step %d: %f' % (step, l))
                print('epoch : ',epoch+1, ' => ', 'Minibatch accuracy: %.1f%%' % accu)
                print('epoch : ',epoch+1, ' => ', 'Learning rate : ', learning_rate)
                print('    ')
        print('------------------------------------------')
        feed_dict = {X : test_d, Y_ : test_l, pkeep : 1.00, alpha : 0.0005}
        _, l, test_pred, W, b = session.run([train_step, cross_entropy, train_prediction, W_s, b_s], feed_dict=feed_dict)
        
        print('Epoch Test accuracy: %.1f%%' % acc(test_pred, test_l[:,1:6]))
        print('Epoch W_s : ', W)
        print('Epoch b_s : ', b)
        print('------------------------------------------')
        print('      ')
                
    print('Training Complete on MNIST Data')    
    save_path = model_saver.save(session, model_to_save)
    print("Model saved in file: %s" % save_path)
# Out:
# Initialized
# epoch :  1  =>  Loss at step 0: 0.865419
# epoch :  1  =>  Minibatch accuracy: 95.2%
# epoch :  1  =>  Learning rate :  0.0005
#
# epoch :  1  =>  Loss at step 500: 0.720889
# epoch :  1  =>  Minibatch accuracy: 95.9%
# epoch :  1  =>  Learning rate :  0.00024715177646857697
#
# epoch :  1  =>  Loss at step 1000: 0.906518
# epoch :  1  =>  Minibatch accuracy: 94.8%
# epoch :  1  =>  Learning rate :  0.0001541341132946451
#
# epoch :  1  =>  Loss at step 1500: 0.766920
# epoch :  1  =>  Minibatch accuracy: 96.1%
# epoch :  1  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.2%
# Epoch W_s :  [ 0.31989142  0.46466604  0.61857241  0.644687  ]
# Epoch b_s :  [ 0.33602604  0.22091122  0.36328185  0.12388856]
# ------------------------------------------
#
# epoch :  2  =>  Loss at step 0: 0.652593
# epoch :  2  =>  Minibatch accuracy: 96.4%
# epoch :  2  =>  Learning rate :  0.0005
#
# epoch :  2  =>  Loss at step 500: 0.645823
# epoch :  2  =>  Minibatch accuracy: 95.9%
# epoch :  2  =>  Learning rate :  0.00024715177646857697
#
# epoch :  2  =>  Loss at step 1000: 0.918374
# epoch :  2  =>  Minibatch accuracy: 95.0%
# epoch :  2  =>  Learning rate :  0.0001541341132946451
#
# epoch :  2  =>  Loss at step 1500: 0.722864
# epoch :  2  =>  Minibatch accuracy: 95.8%
# epoch :  2  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.4%
# Epoch W_s :  [ 0.32271016  0.47507152  0.63686931  0.65642673]
# Epoch b_s :  [ 0.3410261   0.22678509  0.38144615  0.12396573]
# ------------------------------------------
#
# epoch :  3  =>  Loss at step 0: 0.603617
# epoch :  3  =>  Minibatch accuracy: 97.3%
# epoch :  3  =>  Learning rate :  0.0005
#
# epoch :  3  =>  Loss at step 500: 0.587000
# epoch :  3  =>  Minibatch accuracy: 96.9%
# epoch :  3  =>  Learning rate :  0.00024715177646857697
#
# epoch :  3  =>  Loss at step 1000: 0.874401
# epoch :  3  =>  Minibatch accuracy: 95.2%
# epoch :  3  =>  Learning rate :  0.0001541341132946451
#
# epoch :  3  =>  Loss at step 1500: 0.733320
# epoch :  3  =>  Minibatch accuracy: 95.3%
# epoch :  3  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.2%
# Epoch W_s :  [ 0.3261449   0.48373926  0.64358133  0.67027283]
# Epoch b_s :  [ 0.34957033  0.23198636  0.40030617  0.12333626]
# ------------------------------------------
#
# epoch :  4  =>  Loss at step 0: 0.602717
# epoch :  4  =>  Minibatch accuracy: 96.1%
# epoch :  4  =>  Learning rate :  0.0005
#
# epoch :  4  =>  Loss at step 500: 0.566580
# epoch :  4  =>  Minibatch accuracy: 97.3%
# epoch :  4  =>  Learning rate :  0.00024715177646857697
#
# epoch :  4  =>  Loss at step 1000: 0.741362
# epoch :  4  =>  Minibatch accuracy: 95.5%
# epoch :  4  =>  Learning rate :  0.0001541341132946451
#
# epoch :  4  =>  Loss at step 1500: 0.672777
# epoch :  4  =>  Minibatch accuracy: 96.1%
# epoch :  4  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.1%
# Epoch W_s :  [ 0.32969019  0.49154192  0.65691245  0.67783391]
# Epoch b_s :  [ 0.35538015  0.23879796  0.41739163  0.12402267]
# ------------------------------------------
#
# epoch :  5  =>  Loss at step 0: 0.465513
# epoch :  5  =>  Minibatch accuracy: 97.2%
# epoch :  5  =>  Learning rate :  0.0005
#
# epoch :  5  =>  Loss at step 500: 0.512406
# epoch :  5  =>  Minibatch accuracy: 97.5%
# epoch :  5  =>  Learning rate :  0.00024715177646857697
#
# epoch :  5  =>  Loss at step 1000: 0.717792
# epoch :  5  =>  Minibatch accuracy: 95.8%
# epoch :  5  =>  Learning rate :  0.0001541341132946451
#
# epoch :  5  =>  Loss at step 1500: 0.678162
# epoch :  5  =>  Minibatch accuracy: 95.9%
# epoch :  5  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.8%
# Epoch W_s :  [ 0.33420616  0.49814099  0.66368514  0.69127643]
# Epoch b_s :  [ 0.36124045  0.24675997  0.4349812   0.12380278]
# ------------------------------------------
#
# epoch :  6  =>  Loss at step 0: 0.437369
# epoch :  6  =>  Minibatch accuracy: 97.2%
# epoch :  6  =>  Learning rate :  0.0005
#
# epoch :  6  =>  Loss at step 500: 0.566124
# epoch :  6  =>  Minibatch accuracy: 96.2%
# epoch :  6  =>  Learning rate :  0.00024715177646857697
#
# epoch :  6  =>  Loss at step 1000: 0.658722
# epoch :  6  =>  Minibatch accuracy: 96.2%
# epoch :  6  =>  Learning rate :  0.0001541341132946451
#
# epoch :  6  =>  Loss at step 1500: 0.551370
# epoch :  6  =>  Minibatch accuracy: 96.4%
# epoch :  6  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.9%
# Epoch W_s :  [ 0.33762363  0.50510639  0.67705011  0.70881546]
# Epoch b_s :  [ 0.36847323  0.25315899  0.45049554  0.12476826]
# ------------------------------------------
#
# epoch :  7  =>  Loss at step 0: 0.394572
# epoch :  7  =>  Minibatch accuracy: 98.4%
# epoch :  7  =>  Learning rate :  0.0005
#
# epoch :  7  =>  Loss at step 500: 0.473107
# epoch :  7  =>  Minibatch accuracy: 97.3%
# epoch :  7  =>  Learning rate :  0.00024715177646857697
#
# epoch :  7  =>  Loss at step 1000: 0.675974
# epoch :  7  =>  Minibatch accuracy: 95.5%
# epoch :  7  =>  Learning rate :  0.0001541341132946451
#
# epoch :  7  =>  Loss at step 1500: 0.537103
# epoch :  7  =>  Minibatch accuracy: 96.6%
# epoch :  7  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.34246287  0.51406324  0.67649752  0.72021967]
# Epoch b_s :  [ 0.37432352  0.2583352   0.46853748  0.12497246]
# ------------------------------------------
#
# epoch :  8  =>  Loss at step 0: 0.355054
# epoch :  8  =>  Minibatch accuracy: 97.8%
# epoch :  8  =>  Learning rate :  0.0005
#
# epoch :  8  =>  Loss at step 500: 0.447573
# epoch :  8  =>  Minibatch accuracy: 97.7%
# epoch :  8  =>  Learning rate :  0.00024715177646857697
#
# epoch :  8  =>  Loss at step 1000: 0.573048
# epoch :  8  =>  Minibatch accuracy: 96.9%
# epoch :  8  =>  Learning rate :  0.0001541341132946451
#
# epoch :  8  =>  Loss at step 1500: 0.657897
# epoch :  8  =>  Minibatch accuracy: 95.9%
# epoch :  8  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.34705099  0.52368128  0.68456912  0.73692769]
# Epoch b_s :  [ 0.38332093  0.26484182  0.48593751  0.12521888]
# ------------------------------------------
#
# epoch :  9  =>  Loss at step 0: 0.311489
# epoch :  9  =>  Minibatch accuracy: 98.3%
# epoch :  9  =>  Learning rate :  0.0005
#
# epoch :  9  =>  Loss at step 500: 0.379946
# epoch :  9  =>  Minibatch accuracy: 98.0%
# epoch :  9  =>  Learning rate :  0.00024715177646857697
#
# epoch :  9  =>  Loss at step 1000: 0.590647
# epoch :  9  =>  Minibatch accuracy: 96.4%
# epoch :  9  =>  Learning rate :  0.0001541341132946451
#
# epoch :  9  =>  Loss at step 1500: 0.559018
# epoch :  9  =>  Minibatch accuracy: 95.9%
# epoch :  9  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.3%
# Epoch W_s :  [ 0.35076094  0.53068423  0.69524539  0.75035679]
# Epoch b_s :  [ 0.39011723  0.27091435  0.50097966  0.12582383]
# ------------------------------------------
#
# epoch :  10  =>  Loss at step 0: 0.310052
# epoch :  10  =>  Minibatch accuracy: 98.4%
# epoch :  10  =>  Learning rate :  0.0005
#
# epoch :  10  =>  Loss at step 500: 0.405701
# epoch :  10  =>  Minibatch accuracy: 98.3%
# epoch :  10  =>  Learning rate :  0.00024715177646857697
#
# epoch :  10  =>  Loss at step 1000: 0.586851
# epoch :  10  =>  Minibatch accuracy: 96.9%
# epoch :  10  =>  Learning rate :  0.0001541341132946451
#
# epoch :  10  =>  Loss at step 1500: 0.528152
# epoch :  10  =>  Minibatch accuracy: 96.7%
# epoch :  10  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.9%
# Epoch W_s :  [ 0.35471696  0.53785771  0.71099216  0.75152206]
# Epoch b_s :  [ 0.39544249  0.27520743  0.51698494  0.12544625]
# ------------------------------------------
#
# epoch :  11  =>  Loss at step 0: 0.249345
# epoch :  11  =>  Minibatch accuracy: 99.1%
# epoch :  11  =>  Learning rate :  0.0005
#
# epoch :  11  =>  Loss at step 500: 0.378065
# epoch :  11  =>  Minibatch accuracy: 98.3%
# epoch :  11  =>  Learning rate :  0.00024715177646857697
#
# epoch :  11  =>  Loss at step 1000: 0.598747
# epoch :  11  =>  Minibatch accuracy: 96.6%
# epoch :  11  =>  Learning rate :  0.0001541341132946451
#
# epoch :  11  =>  Loss at step 1500: 0.482071
# epoch :  11  =>  Minibatch accuracy: 96.9%
# epoch :  11  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.8%
# Epoch W_s :  [ 0.35943094  0.54535568  0.7161423   0.75862914]
# Epoch b_s :  [ 0.40139982  0.27962252  0.53354853  0.12517126]
# ------------------------------------------
#
# epoch :  12  =>  Loss at step 0: 0.253792
# epoch :  12  =>  Minibatch accuracy: 98.4%
# epoch :  12  =>  Learning rate :  0.0005
#
# epoch :  12  =>  Loss at step 500: 0.377669
# epoch :  12  =>  Minibatch accuracy: 98.1%
# epoch :  12  =>  Learning rate :  0.00024715177646857697
#
# epoch :  12  =>  Loss at step 1000: 0.501928
# epoch :  12  =>  Minibatch accuracy: 97.0%
# epoch :  12  =>  Learning rate :  0.0001541341132946451
#
# epoch :  12  =>  Loss at step 1500: 0.501269
# epoch :  12  =>  Minibatch accuracy: 96.4%
# epoch :  12  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.3640275   0.5532375   0.72516191  0.77252769]
# Epoch b_s :  [ 0.4074316   0.2847023   0.54710138  0.12611426]
# ------------------------------------------
#
# epoch :  13  =>  Loss at step 0: 0.294391
# epoch :  13  =>  Minibatch accuracy: 98.3%
# epoch :  13  =>  Learning rate :  0.0005
#
# epoch :  13  =>  Loss at step 500: 0.380833
# epoch :  13  =>  Minibatch accuracy: 97.8%
# epoch :  13  =>  Learning rate :  0.00024715177646857697
#
# epoch :  13  =>  Loss at step 1000: 0.590458
# epoch :  13  =>  Minibatch accuracy: 96.6%
# epoch :  13  =>  Learning rate :  0.0001541341132946451
#
# epoch :  13  =>  Loss at step 1500: 0.486617
# epoch :  13  =>  Minibatch accuracy: 96.9%
# epoch :  13  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.36872184  0.56012416  0.73310947  0.77859473]
# Epoch b_s :  [ 0.41370878  0.29054198  0.56140292  0.12662166]
# ------------------------------------------
#
# epoch :  14  =>  Loss at step 0: 0.249206
# epoch :  14  =>  Minibatch accuracy: 99.1%
# epoch :  14  =>  Learning rate :  0.0005
#
# epoch :  14  =>  Loss at step 500: 0.324837
# epoch :  14  =>  Minibatch accuracy: 98.3%
# epoch :  14  =>  Learning rate :  0.00024715177646857697
#
# epoch :  14  =>  Loss at step 1000: 0.549739
# epoch :  14  =>  Minibatch accuracy: 96.7%
# epoch :  14  =>  Learning rate :  0.0001541341132946451
#
# epoch :  14  =>  Loss at step 1500: 0.451619
# epoch :  14  =>  Minibatch accuracy: 96.9%
# epoch :  14  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.37487596  0.56529719  0.73896056  0.78704786]
# Epoch b_s :  [ 0.42184371  0.2964837   0.5756405   0.12604906]
# ------------------------------------------
#
# epoch :  15  =>  Loss at step 0: 0.259324
# epoch :  15  =>  Minibatch accuracy: 98.8%
# epoch :  15  =>  Learning rate :  0.0005
#
# epoch :  15  =>  Loss at step 500: 0.348993
# epoch :  15  =>  Minibatch accuracy: 98.4%
# epoch :  15  =>  Learning rate :  0.00024715177646857697
#
# epoch :  15  =>  Loss at step 1000: 0.442316
# epoch :  15  =>  Minibatch accuracy: 97.8%
# epoch :  15  =>  Learning rate :  0.0001541341132946451
#
# epoch :  15  =>  Loss at step 1500: 0.477600
# epoch :  15  =>  Minibatch accuracy: 97.0%
# epoch :  15  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.8%
# Epoch W_s :  [ 0.37938774  0.57380462  0.74638057  0.79774398]
# Epoch b_s :  [ 0.42997444  0.30054528  0.59094679  0.12484357]
# ------------------------------------------
#
# epoch :  16  =>  Loss at step 0: 0.175555
# epoch :  16  =>  Minibatch accuracy: 99.4%
# epoch :  16  =>  Learning rate :  0.0005
#
# epoch :  16  =>  Loss at step 500: 0.317613
# epoch :  16  =>  Minibatch accuracy: 98.1%
# epoch :  16  =>  Learning rate :  0.00024715177646857697
#
# epoch :  16  =>  Loss at step 1000: 0.408571
# epoch :  16  =>  Minibatch accuracy: 97.3%
# epoch :  16  =>  Learning rate :  0.0001541341132946451
#
# epoch :  16  =>  Loss at step 1500: 0.536767
# epoch :  16  =>  Minibatch accuracy: 96.6%
# epoch :  16  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.38523257  0.57806456  0.7553575   0.81113005]
# Epoch b_s :  [ 0.43271878  0.3047187   0.60532027  0.12443145]
# ------------------------------------------
#
# epoch :  17  =>  Loss at step 0: 0.211015
# epoch :  17  =>  Minibatch accuracy: 99.1%
# epoch :  17  =>  Learning rate :  0.0005
#
# epoch :  17  =>  Loss at step 500: 0.303152
# epoch :  17  =>  Minibatch accuracy: 98.1%
# epoch :  17  =>  Learning rate :  0.00024715177646857697
#
# epoch :  17  =>  Loss at step 1000: 0.448692
# epoch :  17  =>  Minibatch accuracy: 97.7%
# epoch :  17  =>  Learning rate :  0.0001541341132946451
#
# epoch :  17  =>  Loss at step 1500: 0.453461
# epoch :  17  =>  Minibatch accuracy: 97.3%
# epoch :  17  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.8%
# Epoch W_s :  [ 0.39074594  0.58189625  0.75490528  0.80659884]
# Epoch b_s :  [ 0.43741387  0.30969721  0.61939663  0.12387165]
# ------------------------------------------
#
# epoch :  18  =>  Loss at step 0: 0.175332
# epoch :  18  =>  Minibatch accuracy: 99.4%
# epoch :  18  =>  Learning rate :  0.0005
#
# epoch :  18  =>  Loss at step 500: 0.308864
# epoch :  18  =>  Minibatch accuracy: 98.0%
# epoch :  18  =>  Learning rate :  0.00024715177646857697
#
# epoch :  18  =>  Loss at step 1000: 0.451752
# epoch :  18  =>  Minibatch accuracy: 97.7%
# epoch :  18  =>  Learning rate :  0.0001541341132946451
#
# epoch :  18  =>  Loss at step 1500: 0.519475
# epoch :  18  =>  Minibatch accuracy: 96.6%
# epoch :  18  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.8%
# Epoch W_s :  [ 0.39562246  0.58586365  0.75855827  0.8247717 ]
# Epoch b_s :  [ 0.44470999  0.31471485  0.63227171  0.12236034]
# ------------------------------------------
#
# epoch :  19  =>  Loss at step 0: 0.179505
# epoch :  19  =>  Minibatch accuracy: 99.1%
# epoch :  19  =>  Learning rate :  0.0005
#
# epoch :  19  =>  Loss at step 500: 0.316385
# epoch :  19  =>  Minibatch accuracy: 98.4%
# epoch :  19  =>  Learning rate :  0.00024715177646857697
#
# epoch :  19  =>  Loss at step 1000: 0.436278
# epoch :  19  =>  Minibatch accuracy: 97.8%
# epoch :  19  =>  Learning rate :  0.0001541341132946451
#
# epoch :  19  =>  Loss at step 1500: 0.566830
# epoch :  19  =>  Minibatch accuracy: 96.2%
# epoch :  19  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.0%
# Epoch W_s :  [ 0.40036219  0.59109706  0.76654172  0.83412492]
# Epoch b_s :  [ 0.45120293  0.32076368  0.64583164  0.12340917]
# ------------------------------------------
#
# epoch :  20  =>  Loss at step 0: 0.166546
# epoch :  20  =>  Minibatch accuracy: 99.4%
# epoch :  20  =>  Learning rate :  0.0005
#
# epoch :  20  =>  Loss at step 500: 0.334878
# epoch :  20  =>  Minibatch accuracy: 98.0%
# epoch :  20  =>  Learning rate :  0.00024715177646857697
#
# epoch :  20  =>  Loss at step 1000: 0.419704
# epoch :  20  =>  Minibatch accuracy: 97.0%
# epoch :  20  =>  Learning rate :  0.0001541341132946451
#
# epoch :  20  =>  Loss at step 1500: 0.487745
# epoch :  20  =>  Minibatch accuracy: 96.1%
# epoch :  20  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.1%
# Epoch W_s :  [ 0.40538955  0.59456813  0.77421302  0.83360207]
# Epoch b_s :  [ 0.45326981  0.32590717  0.66005433  0.12240268]
# ------------------------------------------
#
# epoch :  21  =>  Loss at step 0: 0.159585
# epoch :  21  =>  Minibatch accuracy: 99.1%
# epoch :  21  =>  Learning rate :  0.0005
#
# epoch :  21  =>  Loss at step 500: 0.224547
# epoch :  21  =>  Minibatch accuracy: 98.9%
# epoch :  21  =>  Learning rate :  0.00024715177646857697
#
# epoch :  21  =>  Loss at step 1000: 0.411962
# epoch :  21  =>  Minibatch accuracy: 97.8%
# epoch :  21  =>  Learning rate :  0.0001541341132946451
#
# epoch :  21  =>  Loss at step 1500: 0.409795
# epoch :  21  =>  Minibatch accuracy: 97.2%
# epoch :  21  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.5%
# Epoch W_s :  [ 0.41020083  0.59922159  0.77690768  0.82876527]
# Epoch b_s :  [ 0.45888898  0.32974532  0.6746133   0.1238633 ]
# ------------------------------------------
#
# epoch :  22  =>  Loss at step 0: 0.146743
# epoch :  22  =>  Minibatch accuracy: 99.5%
# epoch :  22  =>  Learning rate :  0.0005
#
# epoch :  22  =>  Loss at step 500: 0.255617
# epoch :  22  =>  Minibatch accuracy: 98.6%
# epoch :  22  =>  Learning rate :  0.00024715177646857697
#
# epoch :  22  =>  Loss at step 1000: 0.425012
# epoch :  22  =>  Minibatch accuracy: 97.5%
# epoch :  22  =>  Learning rate :  0.0001541341132946451
#
# epoch :  22  =>  Loss at step 1500: 0.421228
# epoch :  22  =>  Minibatch accuracy: 97.2%
# epoch :  22  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.2%
# Epoch W_s :  [ 0.41603777  0.60347825  0.79048204  0.83276594]
# Epoch b_s :  [ 0.46068066  0.33446974  0.68552995  0.12320519]
# ------------------------------------------
#
# epoch :  23  =>  Loss at step 0: 0.110976
# epoch :  23  =>  Minibatch accuracy: 99.7%
# epoch :  23  =>  Learning rate :  0.0005
#
# epoch :  23  =>  Loss at step 500: 0.214250
# epoch :  23  =>  Minibatch accuracy: 98.4%
# epoch :  23  =>  Learning rate :  0.00024715177646857697
#
# epoch :  23  =>  Loss at step 1000: 0.366989
# epoch :  23  =>  Minibatch accuracy: 98.3%
# epoch :  23  =>  Learning rate :  0.0001541341132946451
#
# epoch :  23  =>  Loss at step 1500: 0.440684
# epoch :  23  =>  Minibatch accuracy: 97.2%
# epoch :  23  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.4%
# Epoch W_s :  [ 0.41921788  0.60770935  0.79431152  0.84160161]
# Epoch b_s :  [ 0.46444818  0.33784768  0.69600254  0.12412542]
# ------------------------------------------
#
# epoch :  24  =>  Loss at step 0: 0.141120
# epoch :  24  =>  Minibatch accuracy: 99.5%
# epoch :  24  =>  Learning rate :  0.0005
#
# epoch :  24  =>  Loss at step 500: 0.196141
# epoch :  24  =>  Minibatch accuracy: 98.3%
# epoch :  24  =>  Learning rate :  0.00024715177646857697
#
# epoch :  24  =>  Loss at step 1000: 0.381516
# epoch :  24  =>  Minibatch accuracy: 98.0%
# epoch :  24  =>  Learning rate :  0.0001541341132946451
#
# epoch :  24  =>  Loss at step 1500: 0.400382
# epoch :  24  =>  Minibatch accuracy: 96.9%
# epoch :  24  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.4%
# Epoch W_s :  [ 0.42512837  0.60804319  0.78331286  0.84480762]
# Epoch b_s :  [ 0.46961027  0.34079072  0.7086513   0.12464428]
# ------------------------------------------
#
# epoch :  25  =>  Loss at step 0: 0.120636
# epoch :  25  =>  Minibatch accuracy: 99.7%
# epoch :  25  =>  Learning rate :  0.0005
#
# epoch :  25  =>  Loss at step 500: 0.197328
# epoch :  25  =>  Minibatch accuracy: 98.9%
# epoch :  25  =>  Learning rate :  0.00024715177646857697
#
# epoch :  25  =>  Loss at step 1000: 0.364464
# epoch :  25  =>  Minibatch accuracy: 98.8%
# epoch :  25  =>  Learning rate :  0.0001541341132946451
#
# epoch :  25  =>  Loss at step 1500: 0.342747
# epoch :  25  =>  Minibatch accuracy: 97.7%
# epoch :  25  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.42947987  0.61355174  0.79191977  0.85305768]
# Epoch b_s :  [ 0.47446588  0.34574088  0.72066522  0.12523022]
# ------------------------------------------
#
# epoch :  26  =>  Loss at step 0: 0.166176
# epoch :  26  =>  Minibatch accuracy: 99.2%
# epoch :  26  =>  Learning rate :  0.0005
#
# epoch :  26  =>  Loss at step 500: 0.257045
# epoch :  26  =>  Minibatch accuracy: 98.3%
# epoch :  26  =>  Learning rate :  0.00024715177646857697
#
# epoch :  26  =>  Loss at step 1000: 0.360385
# epoch :  26  =>  Minibatch accuracy: 98.1%
# epoch :  26  =>  Learning rate :  0.0001541341132946451
#
# epoch :  26  =>  Loss at step 1500: 0.428098
# epoch :  26  =>  Minibatch accuracy: 96.6%
# epoch :  26  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.2%
# Epoch W_s :  [ 0.43299121  0.61798048  0.80019492  0.85265321]
# Epoch b_s :  [ 0.4796572   0.34774342  0.72948426  0.12562589]
# ------------------------------------------
#
# epoch :  27  =>  Loss at step 0: 0.125875
# epoch :  27  =>  Minibatch accuracy: 99.2%
# epoch :  27  =>  Learning rate :  0.0005
#
# epoch :  27  =>  Loss at step 500: 0.180936
# epoch :  27  =>  Minibatch accuracy: 98.9%
# epoch :  27  =>  Learning rate :  0.00024715177646857697
#
# epoch :  27  =>  Loss at step 1000: 0.314031
# epoch :  27  =>  Minibatch accuracy: 98.4%
# epoch :  27  =>  Learning rate :  0.0001541341132946451
#
# epoch :  27  =>  Loss at step 1500: 0.389473
# epoch :  27  =>  Minibatch accuracy: 97.7%
# epoch :  27  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.43600708  0.61795419  0.80654055  0.85432488]
# Epoch b_s :  [ 0.48385483  0.35317194  0.74031276  0.12561332]
# ------------------------------------------
#
# epoch :  28  =>  Loss at step 0: 0.123678
# epoch :  28  =>  Minibatch accuracy: 99.7%
# epoch :  28  =>  Learning rate :  0.0005
#
# epoch :  28  =>  Loss at step 500: 0.213429
# epoch :  28  =>  Minibatch accuracy: 98.6%
# epoch :  28  =>  Learning rate :  0.00024715177646857697
#
# epoch :  28  =>  Loss at step 1000: 0.370630
# epoch :  28  =>  Minibatch accuracy: 97.7%
# epoch :  28  =>  Learning rate :  0.0001541341132946451
#
# epoch :  28  =>  Loss at step 1500: 0.360942
# epoch :  28  =>  Minibatch accuracy: 97.8%
# epoch :  28  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.9%
# Epoch W_s :  [ 0.43941513  0.62333816  0.80850685  0.86032426]
# Epoch b_s :  [ 0.48525864  0.35843176  0.75048602  0.12672955]
# ------------------------------------------
#
# epoch :  29  =>  Loss at step 0: 0.119251
# epoch :  29  =>  Minibatch accuracy: 99.5%
# epoch :  29  =>  Learning rate :  0.0005
#
# epoch :  29  =>  Loss at step 500: 0.201262
# epoch :  29  =>  Minibatch accuracy: 98.9%
# epoch :  29  =>  Learning rate :  0.00024715177646857697
#
# epoch :  29  =>  Loss at step 1000: 0.378115
# epoch :  29  =>  Minibatch accuracy: 97.3%
# epoch :  29  =>  Learning rate :  0.0001541341132946451
#
# epoch :  29  =>  Loss at step 1500: 0.328842
# epoch :  29  =>  Minibatch accuracy: 97.5%
# epoch :  29  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.44285578  0.62837166  0.81226355  0.86811763]
# Epoch b_s :  [ 0.49036971  0.36241409  0.75980681  0.1268975 ]
# ------------------------------------------
#
# epoch :  30  =>  Loss at step 0: 0.106818
# epoch :  30  =>  Minibatch accuracy: 99.7%
# epoch :  30  =>  Learning rate :  0.0005
#
# epoch :  30  =>  Loss at step 500: 0.144973
# epoch :  30  =>  Minibatch accuracy: 99.1%
# epoch :  30  =>  Learning rate :  0.00024715177646857697
#
# epoch :  30  =>  Loss at step 1000: 0.342081
# epoch :  30  =>  Minibatch accuracy: 98.1%
# epoch :  30  =>  Learning rate :  0.0001541341132946451
#
# epoch :  30  =>  Loss at step 1500: 0.359911
# epoch :  30  =>  Minibatch accuracy: 97.7%
# epoch :  30  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.4%
# Epoch W_s :  [ 0.4460707   0.63269913  0.81200862  0.87389445]
# Epoch b_s :  [ 0.49075344  0.36815554  0.76986456  0.12799779]
# ------------------------------------------
#
# epoch :  31  =>  Loss at step 0: 0.084991
# epoch :  31  =>  Minibatch accuracy: 99.7%
# epoch :  31  =>  Learning rate :  0.0005
#
# epoch :  31  =>  Loss at step 500: 0.175402
# epoch :  31  =>  Minibatch accuracy: 98.9%
# epoch :  31  =>  Learning rate :  0.00024715177646857697
#
# epoch :  31  =>  Loss at step 1000: 0.246674
# epoch :  31  =>  Minibatch accuracy: 98.9%
# epoch :  31  =>  Learning rate :  0.0001541341132946451
#
# epoch :  31  =>  Loss at step 1500: 0.344350
# epoch :  31  =>  Minibatch accuracy: 97.2%
# epoch :  31  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.1%
# Epoch W_s :  [ 0.44917971  0.63757688  0.81681657  0.87255657]
# Epoch b_s :  [ 0.49409533  0.37175     0.78030431  0.12734778]
# ------------------------------------------
#
# epoch :  32  =>  Loss at step 0: 0.119845
# epoch :  32  =>  Minibatch accuracy: 99.8%
# epoch :  32  =>  Learning rate :  0.0005
#
# epoch :  32  =>  Loss at step 500: 0.168752
# epoch :  32  =>  Minibatch accuracy: 99.1%
# epoch :  32  =>  Learning rate :  0.00024715177646857697
#
# epoch :  32  =>  Loss at step 1000: 0.303394
# epoch :  32  =>  Minibatch accuracy: 98.4%
# epoch :  32  =>  Learning rate :  0.0001541341132946451
#
# epoch :  32  =>  Loss at step 1500: 0.476602
# epoch :  32  =>  Minibatch accuracy: 96.4%
# epoch :  32  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.45368755  0.64590979  0.82562816  0.88316309]
# Epoch b_s :  [ 0.49717382  0.3778621   0.79043686  0.12750457]
# ------------------------------------------
#
# epoch :  33  =>  Loss at step 0: 0.109973
# epoch :  33  =>  Minibatch accuracy: 99.5%
# epoch :  33  =>  Learning rate :  0.0005
#
# epoch :  33  =>  Loss at step 500: 0.181569
# epoch :  33  =>  Minibatch accuracy: 99.1%
# epoch :  33  =>  Learning rate :  0.00024715177646857697
#
# epoch :  33  =>  Loss at step 1000: 0.312275
# epoch :  33  =>  Minibatch accuracy: 98.0%
# epoch :  33  =>  Learning rate :  0.0001541341132946451
#
# epoch :  33  =>  Loss at step 1500: 0.338299
# epoch :  33  =>  Minibatch accuracy: 97.8%
# epoch :  33  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 91.2%
# Epoch W_s :  [ 0.45598128  0.65060484  0.82820612  0.88355935]
# Epoch b_s :  [ 0.49892831  0.38134438  0.79880279  0.12715888]
# ------------------------------------------
#
# epoch :  34  =>  Loss at step 0: 0.102816
# epoch :  34  =>  Minibatch accuracy: 99.8%
# epoch :  34  =>  Learning rate :  0.0005
#
# epoch :  34  =>  Loss at step 500: 0.183429
# epoch :  34  =>  Minibatch accuracy: 98.6%
# epoch :  34  =>  Learning rate :  0.00024715177646857697
#
# epoch :  34  =>  Loss at step 1000: 0.259659
# epoch :  34  =>  Minibatch accuracy: 98.6%
# epoch :  34  =>  Learning rate :  0.0001541341132946451
#
# epoch :  34  =>  Loss at step 1500: 0.438929
# epoch :  34  =>  Minibatch accuracy: 96.4%
# epoch :  34  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.45978132  0.65690625  0.83451509  0.89135063]
# Epoch b_s :  [ 0.50095367  0.38626188  0.8059395   0.12709443]
# ------------------------------------------
#
# epoch :  35  =>  Loss at step 0: 0.110487
# epoch :  35  =>  Minibatch accuracy: 99.4%
# epoch :  35  =>  Learning rate :  0.0005
#
# epoch :  35  =>  Loss at step 500: 0.135526
# epoch :  35  =>  Minibatch accuracy: 99.1%
# epoch :  35  =>  Learning rate :  0.00024715177646857697
#
# epoch :  35  =>  Loss at step 1000: 0.347590
# epoch :  35  =>  Minibatch accuracy: 97.7%
# epoch :  35  =>  Learning rate :  0.0001541341132946451
#
# epoch :  35  =>  Loss at step 1500: 0.262796
# epoch :  35  =>  Minibatch accuracy: 98.4%
# epoch :  35  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.46234635  0.66961896  0.83294588  0.90178329]
# Epoch b_s :  [ 0.50122654  0.39090237  0.8167271   0.12780675]
# ------------------------------------------
#
# epoch :  36  =>  Loss at step 0: 0.116916
# epoch :  36  =>  Minibatch accuracy: 99.4%
# epoch :  36  =>  Learning rate :  0.0005
#
# epoch :  36  =>  Loss at step 500: 0.150810
# epoch :  36  =>  Minibatch accuracy: 99.2%
# epoch :  36  =>  Learning rate :  0.00024715177646857697
#
# epoch :  36  =>  Loss at step 1000: 0.429301
# epoch :  36  =>  Minibatch accuracy: 97.2%
# epoch :  36  =>  Learning rate :  0.0001541341132946451
#
# epoch :  36  =>  Loss at step 1500: 0.311147
# epoch :  36  =>  Minibatch accuracy: 97.2%
# epoch :  36  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.3%
# Epoch W_s :  [ 0.46423852  0.676727    0.84036708  0.92106825]
# Epoch b_s :  [ 0.50334084  0.39373747  0.82668769  0.12742268]
# ------------------------------------------
#
# epoch :  37  =>  Loss at step 0: 0.128654
# epoch :  37  =>  Minibatch accuracy: 98.8%
# epoch :  37  =>  Learning rate :  0.0005
#
# epoch :  37  =>  Loss at step 500: 0.144028
# epoch :  37  =>  Minibatch accuracy: 99.2%
# epoch :  37  =>  Learning rate :  0.00024715177646857697
#
# epoch :  37  =>  Loss at step 1000: 0.260874
# epoch :  37  =>  Minibatch accuracy: 98.3%
# epoch :  37  =>  Learning rate :  0.0001541341132946451
#
# epoch :  37  =>  Loss at step 1500: 0.390343
# epoch :  37  =>  Minibatch accuracy: 97.2%
# epoch :  37  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.5%
# Epoch W_s :  [ 0.4683781   0.68092567  0.84579712  0.93008077]
# Epoch b_s :  [ 0.50738996  0.39776465  0.83526361  0.12768677]
# ------------------------------------------
#
# epoch :  38  =>  Loss at step 0: 0.089587
# epoch :  38  =>  Minibatch accuracy: 99.7%
# epoch :  38  =>  Learning rate :  0.0005
#
# epoch :  38  =>  Loss at step 500: 0.183831
# epoch :  38  =>  Minibatch accuracy: 99.1%
# epoch :  38  =>  Learning rate :  0.00024715177646857697
#
# epoch :  38  =>  Loss at step 1000: 0.394337
# epoch :  38  =>  Minibatch accuracy: 98.1%
# epoch :  38  =>  Learning rate :  0.0001541341132946451
#
# epoch :  38  =>  Loss at step 1500: 0.306660
# epoch :  38  =>  Minibatch accuracy: 97.8%
# epoch :  38  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.4714351   0.68761647  0.84566069  0.91776419]
# Epoch b_s :  [ 0.50744325  0.39815095  0.84356314  0.12805216]
# ------------------------------------------
#
# epoch :  39  =>  Loss at step 0: 0.125790
# epoch :  39  =>  Minibatch accuracy: 99.2%
# epoch :  39  =>  Learning rate :  0.0005
#
# epoch :  39  =>  Loss at step 500: 0.180500
# epoch :  39  =>  Minibatch accuracy: 99.1%
# epoch :  39  =>  Learning rate :  0.00024715177646857697
#
# epoch :  39  =>  Loss at step 1000: 0.294308
# epoch :  39  =>  Minibatch accuracy: 98.1%
# epoch :  39  =>  Learning rate :  0.0001541341132946451
#
# epoch :  39  =>  Loss at step 1500: 0.360223
# epoch :  39  =>  Minibatch accuracy: 97.0%
# epoch :  39  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.4%
# Epoch W_s :  [ 0.47455576  0.69530523  0.84873617  0.92473966]
# Epoch b_s :  [ 0.50962353  0.40366125  0.85406107  0.12845959]
# ------------------------------------------
#
# epoch :  40  =>  Loss at step 0: 0.076745
# epoch :  40  =>  Minibatch accuracy: 99.7%
# epoch :  40  =>  Learning rate :  0.0005
#
# epoch :  40  =>  Loss at step 500: 0.175331
# epoch :  40  =>  Minibatch accuracy: 99.1%
# epoch :  40  =>  Learning rate :  0.00024715177646857697
#
# epoch :  40  =>  Loss at step 1000: 0.310215
# epoch :  40  =>  Minibatch accuracy: 98.3%
# epoch :  40  =>  Learning rate :  0.0001541341132946451
#
# epoch :  40  =>  Loss at step 1500: 0.289031
# epoch :  40  =>  Minibatch accuracy: 98.3%
# epoch :  40  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.5%
# Epoch W_s :  [ 0.47731638  0.69546062  0.84477413  0.93111312]
# Epoch b_s :  [ 0.51328933  0.40715376  0.86013335  0.12907444]
# ------------------------------------------
#
# epoch :  41  =>  Loss at step 0: 0.156882
# epoch :  41  =>  Minibatch accuracy: 98.8%
# epoch :  41  =>  Learning rate :  0.0005
#
# epoch :  41  =>  Loss at step 500: 0.194625
# epoch :  41  =>  Minibatch accuracy: 98.4%
# epoch :  41  =>  Learning rate :  0.00024715177646857697
#
# epoch :  41  =>  Loss at step 1000: 0.304916
# epoch :  41  =>  Minibatch accuracy: 98.1%
# epoch :  41  =>  Learning rate :  0.0001541341132946451
#
# epoch :  41  =>  Loss at step 1500: 0.289479
# epoch :  41  =>  Minibatch accuracy: 97.5%
# epoch :  41  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.0%
# Epoch W_s :  [ 0.47997674  0.70097792  0.84346348  0.94066083]
# Epoch b_s :  [ 0.51651531  0.41064098  0.86959946  0.12881327]
# ------------------------------------------
#
# epoch :  42  =>  Loss at step 0: 0.061566
# epoch :  42  =>  Minibatch accuracy: 99.7%
# epoch :  42  =>  Learning rate :  0.0005
#
# epoch :  42  =>  Loss at step 500: 0.179060
# epoch :  42  =>  Minibatch accuracy: 98.6%
# epoch :  42  =>  Learning rate :  0.00024715177646857697
#
# epoch :  42  =>  Loss at step 1000: 0.278324
# epoch :  42  =>  Minibatch accuracy: 98.0%
# epoch :  42  =>  Learning rate :  0.0001541341132946451
#
# epoch :  42  =>  Loss at step 1500: 0.260823
# epoch :  42  =>  Minibatch accuracy: 98.1%
# epoch :  42  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.5%
# Epoch W_s :  [ 0.481848    0.71302414  0.84853053  0.94184262]
# Epoch b_s :  [ 0.51753163  0.41184804  0.87826592  0.13056973]
# ------------------------------------------
#
# epoch :  43  =>  Loss at step 0: 0.099876
# epoch :  43  =>  Minibatch accuracy: 99.5%
# epoch :  43  =>  Learning rate :  0.0005
#
# epoch :  43  =>  Loss at step 500: 0.165014
# epoch :  43  =>  Minibatch accuracy: 99.1%
# epoch :  43  =>  Learning rate :  0.00024715177646857697
#
# epoch :  43  =>  Loss at step 1000: 0.276866
# epoch :  43  =>  Minibatch accuracy: 97.5%
# epoch :  43  =>  Learning rate :  0.0001541341132946451
#
# epoch :  43  =>  Loss at step 1500: 0.312629
# epoch :  43  =>  Minibatch accuracy: 97.3%
# epoch :  43  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.0%
# Epoch W_s :  [ 0.48339656  0.72174531  0.85161108  0.94942552]
# Epoch b_s :  [ 0.51619005  0.41607153  0.88432586  0.13154821]
# ------------------------------------------
#
# epoch :  44  =>  Loss at step 0: 0.076710
# epoch :  44  =>  Minibatch accuracy: 99.7%
# epoch :  44  =>  Learning rate :  0.0005
#
# epoch :  44  =>  Loss at step 500: 0.139272
# epoch :  44  =>  Minibatch accuracy: 99.5%
# epoch :  44  =>  Learning rate :  0.00024715177646857697
#
# epoch :  44  =>  Loss at step 1000: 0.309523
# epoch :  44  =>  Minibatch accuracy: 97.7%
# epoch :  44  =>  Learning rate :  0.0001541341132946451
#
# epoch :  44  =>  Loss at step 1500: 0.322219
# epoch :  44  =>  Minibatch accuracy: 97.0%
# epoch :  44  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.1%
# Epoch W_s :  [ 0.48671535  0.72831619  0.85377097  0.95734596]
# Epoch b_s :  [ 0.52117032  0.42060068  0.89339465  0.13131949]
# ------------------------------------------
#
# epoch :  45  =>  Loss at step 0: 0.113557
# epoch :  45  =>  Minibatch accuracy: 99.4%
# epoch :  45  =>  Learning rate :  0.0005
#
# epoch :  45  =>  Loss at step 500: 0.146160
# epoch :  45  =>  Minibatch accuracy: 98.9%
# epoch :  45  =>  Learning rate :  0.00024715177646857697
#
# epoch :  45  =>  Loss at step 1000: 0.357924
# epoch :  45  =>  Minibatch accuracy: 97.7%
# epoch :  45  =>  Learning rate :  0.0001541341132946451
#
# epoch :  45  =>  Loss at step 1500: 0.309464
# epoch :  45  =>  Minibatch accuracy: 97.3%
# epoch :  45  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.6%
# Epoch W_s :  [ 0.48989809  0.73591703  0.85345995  0.96234101]
# Epoch b_s :  [ 0.52300531  0.42279416  0.89736032  0.12989426]
# ------------------------------------------
#
# epoch :  46  =>  Loss at step 0: 0.107579
# epoch :  46  =>  Minibatch accuracy: 99.1%
# epoch :  46  =>  Learning rate :  0.0005
#
# epoch :  46  =>  Loss at step 500: 0.136150
# epoch :  46  =>  Minibatch accuracy: 99.1%
# epoch :  46  =>  Learning rate :  0.00024715177646857697
#
# epoch :  46  =>  Loss at step 1000: 0.246893
# epoch :  46  =>  Minibatch accuracy: 97.7%
# epoch :  46  =>  Learning rate :  0.0001541341132946451
#
# epoch :  46  =>  Loss at step 1500: 0.289412
# epoch :  46  =>  Minibatch accuracy: 97.7%
# epoch :  46  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.49120811  0.73826164  0.85925084  0.9723984 ]
# Epoch b_s :  [ 0.52426648  0.42464486  0.9066295   0.129476  ]
# ------------------------------------------
#
# epoch :  47  =>  Loss at step 0: 0.046533
# epoch :  47  =>  Minibatch accuracy: 100.0%
# epoch :  47  =>  Learning rate :  0.0005
#
# epoch :  47  =>  Loss at step 500: 0.126822
# epoch :  47  =>  Minibatch accuracy: 99.2%
# epoch :  47  =>  Learning rate :  0.00024715177646857697
#
# epoch :  47  =>  Loss at step 1000: 0.220624
# epoch :  47  =>  Minibatch accuracy: 99.1%
# epoch :  47  =>  Learning rate :  0.0001541341132946451
#
# epoch :  47  =>  Loss at step 1500: 0.295499
# epoch :  47  =>  Minibatch accuracy: 98.1%
# epoch :  47  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 96.7%
# Epoch W_s :  [ 0.49454963  0.74021655  0.86978722  0.97676212]
# Epoch b_s :  [ 0.52558529  0.42524132  0.91653556  0.12946822]
# ------------------------------------------
#
# epoch :  48  =>  Loss at step 0: 0.084499
# epoch :  48  =>  Minibatch accuracy: 99.8%
# epoch :  48  =>  Learning rate :  0.0005
#
# epoch :  48  =>  Loss at step 500: 0.188046
# epoch :  48  =>  Minibatch accuracy: 98.6%
# epoch :  48  =>  Learning rate :  0.00024715177646857697
#
# epoch :  48  =>  Loss at step 1000: 0.251539
# epoch :  48  =>  Minibatch accuracy: 98.3%
# epoch :  48  =>  Learning rate :  0.0001541341132946451
#
# epoch :  48  =>  Loss at step 1500: 0.250490
# epoch :  48  =>  Minibatch accuracy: 98.3%
# epoch :  48  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.8%
# Epoch W_s :  [ 0.49403623  0.74177712  0.86412847  0.97862828]
# Epoch b_s :  [ 0.52475584  0.42789701  0.92320192  0.12970671]
# ------------------------------------------
#
# epoch :  49  =>  Loss at step 0: 0.099121
# epoch :  49  =>  Minibatch accuracy: 99.2%
# epoch :  49  =>  Learning rate :  0.0005
#
# epoch :  49  =>  Loss at step 500: 0.151580
# epoch :  49  =>  Minibatch accuracy: 98.9%
# epoch :  49  =>  Learning rate :  0.00024715177646857697
#
# epoch :  49  =>  Loss at step 1000: 0.253038
# epoch :  49  =>  Minibatch accuracy: 98.6%
# epoch :  49  =>  Learning rate :  0.0001541341132946451
#
# epoch :  49  =>  Loss at step 1500: 0.326944
# epoch :  49  =>  Minibatch accuracy: 97.7%
# epoch :  49  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.0%
# Epoch W_s :  [ 0.49702242  0.74778396  0.86375916  0.98399979]
# Epoch b_s :  [ 0.52527487  0.43018147  0.92876965  0.12942004]
# ------------------------------------------
#
# epoch :  50  =>  Loss at step 0: 0.094801
# epoch :  50  =>  Minibatch accuracy: 99.2%
# epoch :  50  =>  Learning rate :  0.0005
#
# epoch :  50  =>  Loss at step 500: 0.142738
# epoch :  50  =>  Minibatch accuracy: 98.9%
# epoch :  50  =>  Learning rate :  0.00024715177646857697
#
# epoch :  50  =>  Loss at step 1000: 0.303588
# epoch :  50  =>  Minibatch accuracy: 97.8%
# epoch :  50  =>  Learning rate :  0.0001541341132946451
#
# epoch :  50  =>  Loss at step 1500: 0.276922
# epoch :  50  =>  Minibatch accuracy: 98.1%
# epoch :  50  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.7%
# Epoch W_s :  [ 0.49777323  0.75897527  0.86125833  0.98961085]
# Epoch b_s :  [ 0.52948457  0.43090922  0.9366439   0.13019407]
# ------------------------------------------
#
# epoch :  51  =>  Loss at step 0: 0.103640
# epoch :  51  =>  Minibatch accuracy: 99.5%
# epoch :  51  =>  Learning rate :  0.0005
#
# epoch :  51  =>  Loss at step 500: 0.135841
# epoch :  51  =>  Minibatch accuracy: 99.1%
# epoch :  51  =>  Learning rate :  0.00024715177646857697
#
# epoch :  51  =>  Loss at step 1000: 0.225249
# epoch :  51  =>  Minibatch accuracy: 98.6%
# epoch :  51  =>  Learning rate :  0.0001541341132946451
#
# epoch :  51  =>  Loss at step 1500: 0.337106
# epoch :  51  =>  Minibatch accuracy: 97.8%
# epoch :  51  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.2%
# Epoch W_s :  [ 0.50050902  0.7623564   0.86251479  0.9871037 ]
# Epoch b_s :  [ 0.5292092   0.43476135  0.94411403  0.12903723]
# ------------------------------------------
#
# epoch :  52  =>  Loss at step 0: 0.073290
# epoch :  52  =>  Minibatch accuracy: 99.7%
# epoch :  52  =>  Learning rate :  0.0005
#
# epoch :  52  =>  Loss at step 500: 0.143292
# epoch :  52  =>  Minibatch accuracy: 98.9%
# epoch :  52  =>  Learning rate :  0.00024715177646857697
#
# epoch :  52  =>  Loss at step 1000: 0.193081
# epoch :  52  =>  Minibatch accuracy: 99.1%
# epoch :  52  =>  Learning rate :  0.0001541341132946451
#
# epoch :  52  =>  Loss at step 1500: 0.289137
# epoch :  52  =>  Minibatch accuracy: 97.8%
# epoch :  52  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.4%
# Epoch W_s :  [ 0.50230539  0.76576245  0.86110288  0.98745608]
# Epoch b_s :  [ 0.52683693  0.43708912  0.95117146  0.12815772]
# ------------------------------------------
#
# epoch :  53  =>  Loss at step 0: 0.077511
# epoch :  53  =>  Minibatch accuracy: 99.8%
# epoch :  53  =>  Learning rate :  0.0005
#
# epoch :  53  =>  Loss at step 500: 0.138800
# epoch :  53  =>  Minibatch accuracy: 98.9%
# epoch :  53  =>  Learning rate :  0.00024715177646857697
#
# epoch :  53  =>  Loss at step 1000: 0.247381
# epoch :  53  =>  Minibatch accuracy: 98.4%
# epoch :  53  =>  Learning rate :  0.0001541341132946451
#
# epoch :  53  =>  Loss at step 1500: 0.300745
# epoch :  53  =>  Minibatch accuracy: 98.1%
# epoch :  53  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.8%
# Epoch W_s :  [ 0.50288439  0.7622366   0.86508912  0.9823575 ]
# Epoch b_s :  [ 0.52689952  0.44087476  0.95828581  0.12838621]
# ------------------------------------------
#
# epoch :  54  =>  Loss at step 0: 0.063383
# epoch :  54  =>  Minibatch accuracy: 99.7%
# epoch :  54  =>  Learning rate :  0.0005
#
# epoch :  54  =>  Loss at step 500: 0.104169
# epoch :  54  =>  Minibatch accuracy: 99.7%
# epoch :  54  =>  Learning rate :  0.00024715177646857697
#
# epoch :  54  =>  Loss at step 1000: 0.224622
# epoch :  54  =>  Minibatch accuracy: 98.3%
# epoch :  54  =>  Learning rate :  0.0001541341132946451
#
# epoch :  54  =>  Loss at step 1500: 0.253133
# epoch :  54  =>  Minibatch accuracy: 98.4%
# epoch :  54  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.1%
# Epoch W_s :  [ 0.50421286  0.76150292  0.87346411  0.99336785]
# Epoch b_s :  [ 0.52882415  0.44226694  0.96302783  0.12922402]
# ------------------------------------------
#
# epoch :  55  =>  Loss at step 0: 0.097003
# epoch :  55  =>  Minibatch accuracy: 99.5%
# epoch :  55  =>  Learning rate :  0.0005
#
# epoch :  55  =>  Loss at step 500: 0.154502
# epoch :  55  =>  Minibatch accuracy: 98.9%
# epoch :  55  =>  Learning rate :  0.00024715177646857697
#
# epoch :  55  =>  Loss at step 1000: 0.268144
# epoch :  55  =>  Minibatch accuracy: 98.4%
# epoch :  55  =>  Learning rate :  0.0001541341132946451
#
# epoch :  55  =>  Loss at step 1500: 0.282398
# epoch :  55  =>  Minibatch accuracy: 98.0%
# epoch :  55  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.7%
# Epoch W_s :  [ 0.50609988  0.77036893  0.87875342  0.99686962]
# Epoch b_s :  [ 0.52965033  0.44367096  0.97140253  0.12978862]
# ------------------------------------------
#
# epoch :  56  =>  Loss at step 0: 0.089615
# epoch :  56  =>  Minibatch accuracy: 99.5%
# epoch :  56  =>  Learning rate :  0.0005
#
# epoch :  56  =>  Loss at step 500: 0.157037
# epoch :  56  =>  Minibatch accuracy: 99.1%
# epoch :  56  =>  Learning rate :  0.00024715177646857697
#
# epoch :  56  =>  Loss at step 1000: 0.365339
# epoch :  56  =>  Minibatch accuracy: 98.0%
# epoch :  56  =>  Learning rate :  0.0001541341132946451
#
# epoch :  56  =>  Loss at step 1500: 0.177885
# epoch :  56  =>  Minibatch accuracy: 99.4%
# epoch :  56  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.8%
# Epoch W_s :  [ 0.50604963  0.77979964  0.88062203  0.99759281]
# Epoch b_s :  [ 0.53143847  0.4474369   0.97675514  0.12973699]
# ------------------------------------------
#
# epoch :  57  =>  Loss at step 0: 0.105292
# epoch :  57  =>  Minibatch accuracy: 99.2%
# epoch :  57  =>  Learning rate :  0.0005
#
# epoch :  57  =>  Loss at step 500: 0.141235
# epoch :  57  =>  Minibatch accuracy: 98.8%
# epoch :  57  =>  Learning rate :  0.00024715177646857697
#
# epoch :  57  =>  Loss at step 1000: 0.304754
# epoch :  57  =>  Minibatch accuracy: 97.7%
# epoch :  57  =>  Learning rate :  0.0001541341132946451
#
# epoch :  57  =>  Loss at step 1500: 0.278618
# epoch :  57  =>  Minibatch accuracy: 98.3%
# epoch :  57  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.5%
# Epoch W_s :  [ 0.50814843  0.7856493   0.87714148  1.00632751]
# Epoch b_s :  [ 0.53238493  0.44867918  0.98107809  0.1303017 ]
# ------------------------------------------
#
# epoch :  58  =>  Loss at step 0: 0.108548
# epoch :  58  =>  Minibatch accuracy: 99.2%
# epoch :  58  =>  Learning rate :  0.0005
#
# epoch :  58  =>  Loss at step 500: 0.132831
# epoch :  58  =>  Minibatch accuracy: 99.4%
# epoch :  58  =>  Learning rate :  0.00024715177646857697
#
# epoch :  58  =>  Loss at step 1000: 0.227988
# epoch :  58  =>  Minibatch accuracy: 98.8%
# epoch :  58  =>  Learning rate :  0.0001541341132946451
#
# epoch :  58  =>  Loss at step 1500: 0.214898
# epoch :  58  =>  Minibatch accuracy: 98.4%
# epoch :  58  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.9%
# Epoch W_s :  [ 0.50831419  0.78994429  0.87171727  1.01075578]
# Epoch b_s :  [ 0.53389102  0.45266178  0.98727953  0.12977238]
# ------------------------------------------
#
# epoch :  59  =>  Loss at step 0: 0.079925
# epoch :  59  =>  Minibatch accuracy: 99.8%
# epoch :  59  =>  Learning rate :  0.0005
#
# epoch :  59  =>  Loss at step 500: 0.146736
# epoch :  59  =>  Minibatch accuracy: 98.8%
# ...
# epoch :  85  =>  Minibatch accuracy: 98.9%
# epoch :  85  =>  Learning rate :  0.0001541341132946451
#
# epoch :  85  =>  Loss at step 1500: 0.233545
# epoch :  85  =>  Minibatch accuracy: 98.1%
# epoch :  85  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.53118068  0.86636579  0.91394448  1.0577184 ]
# Epoch b_s :  [ 0.53972667  0.50725698  1.12789583  0.13671924]
# ------------------------------------------
#
# epoch :  86  =>  Loss at step 0: 0.083680
# epoch :  86  =>  Minibatch accuracy: 99.2%
# epoch :  86  =>  Learning rate :  0.0005
#
# epoch :  86  =>  Loss at step 500: 0.122340
# epoch :  86  =>  Minibatch accuracy: 99.2%
# epoch :  86  =>  Learning rate :  0.00024715177646857697
#
# epoch :  86  =>  Loss at step 1000: 0.210060
# epoch :  86  =>  Minibatch accuracy: 98.6%
# epoch :  86  =>  Learning rate :  0.0001541341132946451
#
# epoch :  86  =>  Loss at step 1500: 0.194312
# epoch :  86  =>  Minibatch accuracy: 98.6%
# epoch :  86  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.0%
# Epoch W_s :  [ 0.53122753  0.87160337  0.91881645  1.06800747]
# Epoch b_s :  [ 0.54010332  0.50806886  1.13337696  0.13661355]
# ------------------------------------------
#
# epoch :  87  =>  Loss at step 0: 0.044656
# epoch :  87  =>  Minibatch accuracy: 99.8%
# epoch :  87  =>  Learning rate :  0.0005
#
# epoch :  87  =>  Loss at step 500: 0.088759
# epoch :  87  =>  Minibatch accuracy: 99.5%
# epoch :  87  =>  Learning rate :  0.00024715177646857697
#
# epoch :  87  =>  Loss at step 1000: 0.389799
# epoch :  87  =>  Minibatch accuracy: 98.0%
# epoch :  87  =>  Learning rate :  0.0001541341132946451
#
# epoch :  87  =>  Loss at step 1500: 0.251506
# epoch :  87  =>  Minibatch accuracy: 98.9%
# epoch :  87  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.2%
# Epoch W_s :  [ 0.53279561  0.87458533  0.9238081   1.05944145]
# Epoch b_s :  [ 0.53909516  0.51168704  1.13776588  0.13586561]
# ------------------------------------------
#
# epoch :  88  =>  Loss at step 0: 0.078208
# epoch :  88  =>  Minibatch accuracy: 99.8%
# epoch :  88  =>  Learning rate :  0.0005
#
# epoch :  88  =>  Loss at step 500: 0.119068
# epoch :  88  =>  Minibatch accuracy: 99.4%
# epoch :  88  =>  Learning rate :  0.00024715177646857697
#
# epoch :  88  =>  Loss at step 1000: 0.251675
# epoch :  88  =>  Minibatch accuracy: 98.4%
# epoch :  88  =>  Learning rate :  0.0001541341132946451
#
# epoch :  88  =>  Loss at step 1500: 0.215127
# epoch :  88  =>  Minibatch accuracy: 98.6%
# epoch :  88  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.6%
# Epoch W_s :  [ 0.53096396  0.8803454   0.9245981   1.06178963]
# Epoch b_s :  [ 0.54026121  0.5139026   1.13943958  0.13588083]
# ------------------------------------------
#
# epoch :  89  =>  Loss at step 0: 0.052142
# epoch :  89  =>  Minibatch accuracy: 99.7%
# epoch :  89  =>  Learning rate :  0.0005
#
# epoch :  89  =>  Loss at step 500: 0.149395
# epoch :  89  =>  Minibatch accuracy: 99.2%
# epoch :  89  =>  Learning rate :  0.00024715177646857697
#
# epoch :  89  =>  Loss at step 1000: 0.159704
# epoch :  89  =>  Minibatch accuracy: 98.4%
# epoch :  89  =>  Learning rate :  0.0001541341132946451
#
# epoch :  89  =>  Loss at step 1500: 0.206385
# epoch :  89  =>  Minibatch accuracy: 98.8%
# epoch :  89  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.5%
# Epoch W_s :  [ 0.53119111  0.87976336  0.92063111  1.05609846]
# Epoch b_s :  [ 0.54070824  0.51609516  1.14449489  0.13655484]
# ------------------------------------------
#
# epoch :  90  =>  Loss at step 0: 0.102504
# epoch :  90  =>  Minibatch accuracy: 99.5%
# epoch :  90  =>  Learning rate :  0.0005
#
# epoch :  90  =>  Loss at step 500: 0.141301
# epoch :  90  =>  Minibatch accuracy: 98.9%
# epoch :  90  =>  Learning rate :  0.00024715177646857697
#
# epoch :  90  =>  Loss at step 1000: 0.175018
# epoch :  90  =>  Minibatch accuracy: 98.9%
# epoch :  90  =>  Learning rate :  0.0001541341132946451
#
# epoch :  90  =>  Loss at step 1500: 0.214075
# epoch :  90  =>  Minibatch accuracy: 98.4%
# epoch :  90  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.2%
# Epoch W_s :  [ 0.53258634  0.88349652  0.92180365  1.057266  ]
# Epoch b_s :  [ 0.54210967  0.51856202  1.1463176   0.1360494 ]
# ------------------------------------------
#
# epoch :  91  =>  Loss at step 0: 0.073022
# epoch :  91  =>  Minibatch accuracy: 99.7%
# epoch :  91  =>  Learning rate :  0.0005
#
# epoch :  91  =>  Loss at step 500: 0.108317
# epoch :  91  =>  Minibatch accuracy: 99.1%
# epoch :  91  =>  Learning rate :  0.00024715177646857697
#
# epoch :  91  =>  Loss at step 1000: 0.199241
# epoch :  91  =>  Minibatch accuracy: 98.3%
# epoch :  91  =>  Learning rate :  0.0001541341132946451
#
# epoch :  91  =>  Loss at step 1500: 0.271675
# epoch :  91  =>  Minibatch accuracy: 98.1%
# epoch :  91  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.53281176  0.88234103  0.91845953  1.07199562]
# Epoch b_s :  [ 0.54154062  0.51973033  1.15277708  0.13706939]
# ------------------------------------------
#
# epoch :  92  =>  Loss at step 0: 0.065562
# epoch :  92  =>  Minibatch accuracy: 99.5%
# epoch :  92  =>  Learning rate :  0.0005
#
# epoch :  92  =>  Loss at step 500: 0.064734
# epoch :  92  =>  Minibatch accuracy: 99.7%
# epoch :  92  =>  Learning rate :  0.00024715177646857697
#
# epoch :  92  =>  Loss at step 1000: 0.229129
# epoch :  92  =>  Minibatch accuracy: 98.4%
# epoch :  92  =>  Learning rate :  0.0001541341132946451
#
# epoch :  92  =>  Loss at step 1500: 0.194629
# epoch :  92  =>  Minibatch accuracy: 98.4%
# epoch :  92  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.53451389  0.88827747  0.92277223  1.07776046]
# Epoch b_s :  [ 0.54083282  0.52112705  1.15523863  0.13675414]
# ------------------------------------------
#
# epoch :  93  =>  Loss at step 0: 0.047570
# epoch :  93  =>  Minibatch accuracy: 99.8%
# epoch :  93  =>  Learning rate :  0.0005
#
# epoch :  93  =>  Loss at step 500: 0.083000
# epoch :  93  =>  Minibatch accuracy: 99.2%
# epoch :  93  =>  Learning rate :  0.00024715177646857697
#
# epoch :  93  =>  Loss at step 1000: 0.185965
# epoch :  93  =>  Minibatch accuracy: 98.6%
# epoch :  93  =>  Learning rate :  0.0001541341132946451
#
# epoch :  93  =>  Loss at step 1500: 0.200937
# epoch :  93  =>  Minibatch accuracy: 98.8%
# epoch :  93  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.53431714  0.89334714  0.91715431  1.07808745]
# Epoch b_s :  [ 0.53903848  0.52301657  1.15863907  0.13670573]
# ------------------------------------------
#
# epoch :  94  =>  Loss at step 0: 0.055726
# epoch :  94  =>  Minibatch accuracy: 99.7%
# epoch :  94  =>  Learning rate :  0.0005
#
# epoch :  94  =>  Loss at step 500: 0.127921
# epoch :  94  =>  Minibatch accuracy: 99.1%
# epoch :  94  =>  Learning rate :  0.00024715177646857697
#
# epoch :  94  =>  Loss at step 1000: 0.258097
# epoch :  94  =>  Minibatch accuracy: 98.1%
# epoch :  94  =>  Learning rate :  0.0001541341132946451
#
# epoch :  94  =>  Loss at step 1500: 0.210924
# epoch :  94  =>  Minibatch accuracy: 98.9%
# epoch :  94  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.2%
# Epoch W_s :  [ 0.53457266  0.89875954  0.91522008  1.08441317]
# Epoch b_s :  [ 0.54034752  0.52616477  1.16696799  0.1361725 ]
# ------------------------------------------
#
# epoch :  95  =>  Loss at step 0: 0.063373
# epoch :  95  =>  Minibatch accuracy: 99.5%
# epoch :  95  =>  Learning rate :  0.0005
#
# epoch :  95  =>  Loss at step 500: 0.159507
# epoch :  95  =>  Minibatch accuracy: 99.2%
# epoch :  95  =>  Learning rate :  0.00024715177646857697
#
# epoch :  95  =>  Loss at step 1000: 0.303026
# epoch :  95  =>  Minibatch accuracy: 98.0%
# epoch :  95  =>  Learning rate :  0.0001541341132946451
#
# epoch :  95  =>  Loss at step 1500: 0.158257
# epoch :  95  =>  Minibatch accuracy: 98.9%
# epoch :  95  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.8%
# Epoch W_s :  [ 0.53566504  0.89384609  0.9134171   1.08864892]
# Epoch b_s :  [ 0.54250044  0.52922428  1.17155135  0.13815407]
# ------------------------------------------
#
# epoch :  96  =>  Loss at step 0: 0.071529
# epoch :  96  =>  Minibatch accuracy: 99.7%
# epoch :  96  =>  Learning rate :  0.0005
#
# epoch :  96  =>  Loss at step 500: 0.090690
# epoch :  96  =>  Minibatch accuracy: 99.4%
# epoch :  96  =>  Learning rate :  0.00024715177646857697
#
# epoch :  96  =>  Loss at step 1000: 0.236322
# epoch :  96  =>  Minibatch accuracy: 98.4%
# epoch :  96  =>  Learning rate :  0.0001541341132946451
#
# epoch :  96  =>  Loss at step 1500: 0.254289
# epoch :  96  =>  Minibatch accuracy: 98.6%
# epoch :  96  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 91.7%
# Epoch W_s :  [ 0.53491873  0.89006984  0.90657824  1.08773875]
# Epoch b_s :  [ 0.54214269  0.53141308  1.17632556  0.13858026]
# ------------------------------------------
#
# epoch :  97  =>  Loss at step 0: 0.081778
# epoch :  97  =>  Minibatch accuracy: 99.7%
# epoch :  97  =>  Learning rate :  0.0005
#
# epoch :  97  =>  Loss at step 500: 0.098189
# epoch :  97  =>  Minibatch accuracy: 99.2%
# epoch :  97  =>  Learning rate :  0.00024715177646857697
#
# epoch :  97  =>  Loss at step 1000: 0.204447
# epoch :  97  =>  Minibatch accuracy: 98.6%
# epoch :  97  =>  Learning rate :  0.0001541341132946451
#
# epoch :  97  =>  Loss at step 1500: 0.166860
# epoch :  97  =>  Minibatch accuracy: 98.9%
# epoch :  97  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.9%
# Epoch W_s :  [ 0.53675246  0.88732117  0.91167468  1.09678304]
# Epoch b_s :  [ 0.54446375  0.5309456   1.18422699  0.13946688]
# ------------------------------------------
#
# epoch :  98  =>  Loss at step 0: 0.034266
# epoch :  98  =>  Minibatch accuracy: 99.8%
# epoch :  98  =>  Learning rate :  0.0005
#
# epoch :  98  =>  Loss at step 500: 0.080680
# epoch :  98  =>  Minibatch accuracy: 99.2%
# epoch :  98  =>  Learning rate :  0.00024715177646857697
#
# epoch :  98  =>  Loss at step 1000: 0.108998
# epoch :  98  =>  Minibatch accuracy: 99.2%
# epoch :  98  =>  Learning rate :  0.0001541341132946451
#
# epoch :  98  =>  Loss at step 1500: 0.130877
# epoch :  98  =>  Minibatch accuracy: 99.2%
# epoch :  98  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.2%
# Epoch W_s :  [ 0.53588539  0.89111197  0.91841245  1.10519874]
# Epoch b_s :  [ 0.54381436  0.53333151  1.18596876  0.13673446]
# ------------------------------------------
#
# epoch :  99  =>  Loss at step 0: 0.037925
# epoch :  99  =>  Minibatch accuracy: 99.8%
# epoch :  99  =>  Learning rate :  0.0005
#
# epoch :  99  =>  Loss at step 500: 0.116641
# epoch :  99  =>  Minibatch accuracy: 99.2%
# epoch :  99  =>  Learning rate :  0.00024715177646857697
#
# epoch :  99  =>  Loss at step 1000: 0.100291
# epoch :  99  =>  Minibatch accuracy: 99.4%
# epoch :  99  =>  Learning rate :  0.0001541341132946451
#
# epoch :  99  =>  Loss at step 1500: 0.153275
# epoch :  99  =>  Minibatch accuracy: 98.8%
# epoch :  99  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 92.8%
# Epoch W_s :  [ 0.53580016  0.89374036  0.91661245  1.0981015 ]
# Epoch b_s :  [ 0.54222655  0.53225857  1.18993986  0.13785402]
# ------------------------------------------
#
# epoch :  100  =>  Loss at step 0: 0.026402
# epoch :  100  =>  Minibatch accuracy: 100.0%
# epoch :  100  =>  Learning rate :  0.0005
#
# epoch :  100  =>  Loss at step 500: 0.112159
# epoch :  100  =>  Minibatch accuracy: 98.9%
# epoch :  100  =>  Learning rate :  0.00024715177646857697
#
# epoch :  100  =>  Loss at step 1000: 0.130738
# epoch :  100  =>  Minibatch accuracy: 99.4%
# epoch :  100  =>  Learning rate :  0.0001541341132946451
#
# epoch :  100  =>  Loss at step 1500: 0.203939
# epoch :  100  =>  Minibatch accuracy: 98.4%
# epoch :  100  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.4%
# Epoch W_s :  [ 0.53689903  0.90009028  0.91447532  1.10400391]
# Epoch b_s :  [ 0.54078341  0.53464895  1.1939832   0.13971737]
# ------------------------------------------
#
# epoch :  101  =>  Loss at step 0: 0.060037
# epoch :  101  =>  Minibatch accuracy: 99.7%
# epoch :  101  =>  Learning rate :  0.0005
#
# epoch :  101  =>  Loss at step 500: 0.025474
# epoch :  101  =>  Minibatch accuracy: 100.0%
# epoch :  101  =>  Learning rate :  0.00024715177646857697
#
# epoch :  101  =>  Loss at step 1000: 0.153743
# epoch :  101  =>  Minibatch accuracy: 99.1%
# epoch :  101  =>  Learning rate :  0.0001541341132946451
#
# epoch :  101  =>  Loss at step 1500: 0.193023
# epoch :  101  =>  Minibatch accuracy: 98.6%
# epoch :  101  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 94.4%
# Epoch W_s :  [ 0.53711128  0.89824027  0.90933353  1.10800886]
# Epoch b_s :  [ 0.53998333  0.53578711  1.19843674  0.13961212]
# ------------------------------------------
#
# epoch :  102  =>  Loss at step 0: 0.055148
# epoch :  102  =>  Minibatch accuracy: 99.5%
# epoch :  102  =>  Learning rate :  0.0005
#
# epoch :  102  =>  Loss at step 500: 0.097937
# epoch :  102  =>  Minibatch accuracy: 99.4%
# epoch :  102  =>  Learning rate :  0.00024715177646857697
#
# epoch :  102  =>  Loss at step 1000: 0.203037
# epoch :  102  =>  Minibatch accuracy: 98.6%
# epoch :  102  =>  Learning rate :  0.0001541341132946451
#
# epoch :  102  =>  Loss at step 1500: 0.242133
# epoch :  102  =>  Minibatch accuracy: 98.3%
# epoch :  102  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 95.8%
# Epoch W_s :  [ 0.53583717  0.89652246  0.90708113  1.11830556]
# Epoch b_s :  [ 0.54338837  0.53877163  1.20287371  0.14043388]
# ------------------------------------------
#
# epoch :  103  =>  Loss at step 0: 0.031861
# epoch :  103  =>  Minibatch accuracy: 100.0%
# epoch :  103  =>  Learning rate :  0.0005
#
# epoch :  103  =>  Loss at step 500: 0.093293
# epoch :  103  =>  Minibatch accuracy: 99.5%
# epoch :  103  =>  Learning rate :  0.00024715177646857697
#
# epoch :  103  =>  Loss at step 1000: 0.129198
# epoch :  103  =>  Minibatch accuracy: 98.9%
# epoch :  103  =>  Learning rate :  0.0001541341132946451
#
# epoch :  103  =>  Loss at step 1500: 0.164500
# epoch :  103  =>  Minibatch accuracy: 99.1%
# epoch :  103  =>  Learning rate :  0.00011991482734714559
#
# ------------------------------------------
# Epoch Test accuracy: 93.3%
# Epoch W_s :  [ 0.53575605  0.89874941  0.90667731  1.12120295]
# Epoch b_s :  [ 0.54097897  0.53996044  1.20513451  0.14060083]
# ------------------------------------------
#
# epoch :  104  =>  Loss at step 0: 0.039860
# epoch :  104  =>  Minibatch accuracy: 99.7%
# epoch :  104  =>  Learning rate :  0.0005
#
# epoch :  104  =>  Loss at step 500: 0.110284
# epoch :  104  =>  Minibatch accuracy: 99.4%
# epoch :  104  =>  Learning rate :  0.00024715177646857697
#
# epoch :  104  =>  Loss at step 1000: 0.220386
# epoch :  104  =>  Minibatch accuracy: 98.4%
# epoch :  104  =>  Learning rate :  0.0001541341132946451
#
# epoch :  104  =>  Loss at step 1500: 0.196190
# epoch :  104  =>  Minibatch accuracy: 98.3%
# epoch :  104  =>  Learning rate :  0.00011991482734714559

# %%
with tf.Session(graph=graph_svhn) as session: 
    print('Initialized')
    batch = 1000
        
    valid_acc = list()
    valid_no = int(valid_labels.shape[0] /  batch)
    for i in range(valid_no - 1):
        model_saver.restore(session, model_to_save)
        data = valid_dataset[i*batch:(i+1)*batch]
        labels = valid_labels[i*batch:(i+1)*batch]
        
        _, l, predictions = session.run([train_step, cross_entropy, train_prediction], feed_dict={X : data, Y_ : labels, pkeep : 1.0, alpha : 0.002})
        accuracy = acc(predictions, labels[:,1:6])
        valid_acc.append(accuracy)
        
        print('Valid-Accuracy', ' i : ', i)
        print('Valid accuracy: ', accuracy)
        print('        ')
                
    valid_avg = mean(valid_acc)
    
    print('-----  FINAL  ------')
    print('Final Validation Set Accuracy : ',"%.2f" % valid_avg)
